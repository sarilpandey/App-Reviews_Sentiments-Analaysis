# %%
#Project  (App Reviews_Sentiments Analaysis)

# %%
import pandas as pd

# %%
df=pd.read_csv("/content/linkedin-reviews - linkedin-reviews.csv")

# %%
df.head(3)
# Out:
#                                               Review  Rating
# 0  Does absolutely nothing for a LinkedIn beginne...       1
# 1                            Force close(galaxy tab)       1
# 2  Slow and it tries to upload your contacts with...       1

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set(style = "whitegrid")
plt.figure(figsize =(9,5))
sns.countplot(data = df , x ="Rating")
plt. title('Distribution of Ratings')
plt.xlabel('Rating')
plt.ylabel("Count")
plt.show()

# %%
# !pip install textblob
# Out:
# Requirement already satisfied: textblob in /usr/local/lib/python3.11/dist-packages (0.19.0)
# Requirement already satisfied: nltk>=3.9 in /usr/local/lib/python3.11/dist-packages (from textblob) (3.9.1)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from nltk>=3.9->textblob) (8.2.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from nltk>=3.9->textblob) (1.5.1)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.11/dist-packages (from nltk>=3.9->textblob) (2024.11.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from nltk>=3.9->textblob) (4.67.1)

# %%
from textblob import TextBlob

# %%
def textblob_sentiment_analysis(review):
  sentiment = TextBlob(review).sentiment
  if sentiment.polarity > 0.1:
    return "positively"
  elif sentiment.polarity <-0.1 :
      return "Negative"
  else :
     return "Neutral"

# %%
df['Sentiment'] =df["Review"].apply(textblob_sentiment_analysis)

# %%
df
# Out:
#                                                 Review  Rating   Sentiment
# 0    Does absolutely nothing for a LinkedIn beginne...       1    Negative
# 1                              Force close(galaxy tab)       1     Neutral
# 2    Slow and it tries to upload your contacts with...       1    Negative
# 3    Add ability to customize the profile and move ...       4     Neutral
# 4    Good app, but it's a pain that it's not possib...       4  positively
# ..                                                 ...     ...         ...
# 697  Can't trust, Going to uninstall just for that ...       1     Neutral
# 698  It really gets me linked in with my friends. H...       5  positively
# 699  It lacks most of what makes the other social n...       4  positively
# 700  Really disappointed in the new version. Seems ...       2     Neutral
# 701  One of the best looking and well designed apps...       5  positively
#
# [702 rows x 3 columns]

# %%
df['Sentiment'].value_counts().plot(kind ="pie" , autopct ="%.2f")
# Out:
# <Axes: ylabel='count'>

# %%
plt.figure(figsize = (10,5))
sns.countplot(data =df,
              x = "Rating" ,
              hue = "Sentiment")
plt.xlabel("Rating")
plt.ylabel("Count")
plt.legend(title="Sentoiment")
plt.show()
